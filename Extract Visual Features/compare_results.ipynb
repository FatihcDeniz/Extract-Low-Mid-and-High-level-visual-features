# %% [markdown]
# # Fourier Slope/Sigma

# %%
import os
import time
import pandas as pd
from PIL import Image
import numpy as np

# Import your functions
from utils.AT.fourier_qips import fourier_redies as fourier_qips_func
from utils.AT.fourier_modified import fourier_redies as fourier_modified_func

# Folder with input images
image_folder = r"C:\Users\20225378\Desktop\IDEAS final\Images\bedroom"
n_images = 10
# Store results
results = []

# Loop through images
for filename in os.listdir(image_folder)[:n_images]:
    if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
        file_path = os.path.join(image_folder, filename)

        # Load image
        img = Image.open(file_path).convert("L")
        img_array = np.array(img)

        # ---- First function ----
        start_time = time.time()
        result_qips = fourier_qips_func(img_array)
        time_qips = time.time() - start_time

        # ---- Second function ----
        start_time = time.time()
        result_modified = fourier_modified_func(img_array)
        time_modified = time.time() - start_time

        # Store results
        results.append({
            "image": filename,
            "result_qips": result_qips,
            "time_qips_sec": time_qips,
            "result_modified": result_modified,
            "time_modified_sec": time_modified
        })

        print(f"Processed {filename}")

# Convert to DataFrame
df = pd.DataFrame(results)

print(f"Mean time original {df['time_qips_sec'].mean()} -- Mean time modified {df['time_modified_sec'].mean()}")
df
# Out:
# Processed bedroom__0.png
# Processed bedroom__1.png
# Processed bedroom__10.png
# Processed bedroom__100.png
# Processed bedroom__101.png
# Processed bedroom__102.png
# Processed bedroom__103.png
# Processed bedroom__104.png
# Processed bedroom__105.png
# Processed bedroom__106.png
# Mean time original 6.871877932548523 -- Mean time modified 0.10636193752288818
#               image                                  result_qips  \
# 0    bedroom__0.png   (0.027965298645476602, -2.623679660870999)
# 1    bedroom__1.png    (0.01152963089189481, -2.588536926157409)
# 2   bedroom__10.png  (0.008922766615864062, -2.5837916025824685)
# 3  bedroom__100.png  (0.006114376897780466, -2.8971718490479663)
# 4  bedroom__101.png  (0.008741262311883524, -2.8452225354046794)
# 5  bedroom__102.png   (0.026287575029595684, -2.904149503681903)
# 6  bedroom__103.png  (0.006418841066238741, -2.7610729596798342)
# 7  bedroom__104.png  (0.013315135845424672, -2.9335115370177998)
# 8  bedroom__105.png   (0.005598315448776675, -2.676824335794844)
# 9  bedroom__106.png    (0.008753554913354444, -2.96298646506248)
#
#    time_qips_sec                              result_modified  \
# 0       6.262841   (0.027965298645476602, -2.623679660870999)
# 1       7.705986    (0.01152963089189481, -2.588536926157409)
# 2       7.016212  (0.008922766615864062, -2.5837916025824685)
# 3       7.659732  (0.006114376897780466, -2.8971718490479663)
# 4       6.967124  (0.008741262311883524, -2.8452225354046794)
# 5       7.031161   (0.026287575029595684, -2.904149503681903)
# 6       7.144643  (0.006418841066238741, -2.7610729596798342)
# 7       6.605803  (0.013315135845424672, -2.9335115370177998)
# 8       6.390640   (0.005598315448776675, -2.676824335794844)
# 9       5.934638    (0.008753554913354444, -2.96298646506248)
#
#    time_modified_sec
# 0           0.116076
# 1           0.100941
# 2           0.109359
# 3           0.100945
# 4           0.119874
# 5           0.115821
# 6           0.112061
# 7           0.104579
# 8           0.091357
# 9           0.092606

# %% [markdown]
# #### First order edge density, second order edge density and edge density comparison

# %%
import os
import time
import pandas as pd
from PIL import Image
import numpy as np

# Import your functions
from utils.AT.edge_entropy_qips import do_first_and_second_order_entropy_and_edge_density as edge_density_original
from utils.AT.edge_entropy_modified import first_and_second_order_entropy_and_edge_density as edge_density_modified

# Folder with input images
image_folder = r"C:\Users\20225378\Desktop\IDEAS final\Images\bedroom"
n_images = 10
# Store results
results = []

# Loop through images
for filename in os.listdir(image_folder)[:n_images]:
    if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
        file_path = os.path.join(image_folder, filename)

        # Load image
        img = Image.open(file_path).convert("L")
        img_array = np.array(img)

        # ---- First function ----
        start_time = time.time()
        result_qips = edge_density_original(img_array)
        time_qips = time.time() - start_time

        # ---- Second function ----
        start_time = time.time()
        result_modified = edge_density_modified(img_array)
        time_modified = time.time() - start_time

        # Store results
        results.append({
            "image": filename,
            "result_qips": result_qips,
            "time_qips_sec": time_qips,
            "result_modified": result_modified,
            "time_modified_sec": time_modified
        })

        print(f"Processed {filename}")

# Convert to DataFrame
df = pd.DataFrame(results)

print(f"Mean time original {df['time_qips_sec'].mean()} -- Mean time modified {df['time_modified_sec'].mean()}")
df
# Out:
# Processed bedroom__0.png
# Processed bedroom__1.png
# Processed bedroom__10.png
# Processed bedroom__100.png
# Processed bedroom__101.png
# Processed bedroom__102.png
# Processed bedroom__103.png
# Processed bedroom__104.png
# Processed bedroom__105.png
# Processed bedroom__106.png
# Mean time original 13.949638032913208 -- Mean time modified 3.744343566894531
#               image                                        result_qips  \
# 0    bedroom__0.png  (4.344435855042109, 4.391809070377701, 66.8094...
# 1    bedroom__1.png  (3.8550903216741443, 4.054313504273331, 73.138...
# 2   bedroom__10.png  (4.0264109099514265, 4.153596888428996, 50.806...
# 3  bedroom__100.png  (4.232615052812477, 4.3362710632872075, 58.369...
# 4  bedroom__101.png  (3.8120666694390946, 4.108838574993698, 88.054...
# 5  bedroom__102.png  (4.295910594284571, 4.368033784357571, 74.3637...
# 6  bedroom__103.png  (3.9955069119472926, 4.2341177414868545, 72.19...
# 7  bedroom__104.png  (4.053814904397889, 4.304477883755515, 72.9587...
# 8  bedroom__105.png  (4.3221311388913985, 4.3682814416514555, 71.61...
# 9  bedroom__106.png  (3.538382680971004, 3.894938570292498, 97.2072...
#
#    time_qips_sec                                    result_modified  \
# 0      14.975632  (4.344435855042109, 4.391809070377701, 66.8094...
# 1      13.808002  (3.8550903216741443, 4.054313504273331, 73.138...
# 2      17.729774  (4.0264109099514265, 4.153596888428996, 50.806...
# 3      14.081952  (4.232615052812477, 4.3362710632872075, 58.369...
# 4      12.593857  (3.8120666694390946, 4.108838574993698, 88.054...
# 5      12.697302  (4.295910594284571, 4.368033784357571, 74.3637...
# 6      12.863879  (3.9955069119472926, 4.2341177414868545, 72.19...
# 7      13.497533  (4.053814904397889, 4.304477883755515, 72.9587...
# 8      13.186543  (4.3221311388913985, 4.3682814416514555, 71.61...
# 9      14.061906  (3.538382680971004, 3.894938570292498, 97.2072...
#
#    time_modified_sec
# 0           4.514585
# 1           4.709386
# 2           3.538485
# 3           3.301581
# 4           3.199622
# 5           3.832663
# 6           3.269096
# 7           3.692531
# 8           3.942923
# 9           3.442565

# %% [markdown]
# #### CNN symmetry comparison

# %%
import os
import time
import pandas as pd
from PIL import Image
import numpy as np

# Import your functions
from utils.AT.CNN_qips import CNN_symmetry as symmetry_original
from utils.AT.CNN_modified import CNN_symmetry as symmetry_modified

# Folder with input images
image_folder = r"C:\Users\20225378\Desktop\IDEAS final\Images\bedroom"
[kernel,bias] = np.load(open(r"utils\AT\bvlc_alexnet_conv1.npy", "rb"), encoding="latin1", allow_pickle=True)

# Store results
results = []


# Loop through images
for filename in os.listdir(image_folder)[:n_images]:
    if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
        file_path = os.path.join(image_folder, filename)

        # Load image
        img = Image.open(file_path).resize((224,224))
        img_array = np.array(img)

        # ---- First function ----
        start_time = time.time()
        result_qips = symmetry_original(img_array, kernel, bias)
        time_qips = time.time() - start_time

        # ---- Second function ----
        start_time = time.time()
        result_modified = symmetry_modified(img_array, kernel, bias)
        time_modified = time.time() - start_time

        # Store results
        results.append({
            "image": filename,
            "result_qips": result_qips,
            "time_qips_sec": time_qips,
            "result_modified": result_modified,
            "time_modified_sec": time_modified
        })

        print(f"Processed {filename}")

# Convert to DataFrame
df = pd.DataFrame(results)

print(f"Mean time original {df['time_qips_sec'].mean()} -- Mean time modified {df['time_modified_sec'].mean()}")
df
# Out:
# Processed bedroom__0.png
# Processed bedroom__1.png
# Processed bedroom__10.png
# Processed bedroom__100.png
# Processed bedroom__101.png
# Processed bedroom__102.png
# Processed bedroom__103.png
# Processed bedroom__104.png
# Processed bedroom__105.png
# Processed bedroom__106.png
# Mean time original 13.749721002578735 -- Mean time modified 0.5459633588790893
#               image                                 result_qips  \
# 0    bedroom__0.png    (0.3371057252494143, 0.2298364460344121)
# 1    bedroom__1.png  (0.29204919677858365, 0.18383274802029825)
# 2   bedroom__10.png   (0.3647144925741861, 0.34352486534620974)
# 3  bedroom__100.png   (0.3775027594532202, 0.33143468551200794)
# 4  bedroom__101.png    (0.3750636682364503, 0.3075455498644144)
# 5  bedroom__102.png    (0.3955294954128067, 0.3084933421921797)
# 6  bedroom__103.png    (0.3277796153940623, 0.3721038347837362)
# 7  bedroom__104.png  (0.36896415050657283, 0.40918346586271837)
# 8  bedroom__105.png  (0.31193425432630983, 0.32521446204885573)
# 9  bedroom__106.png   (0.34899982695431697, 0.3887406116029236)
#
#    time_qips_sec                                    result_modified  \
# 0      11.487357  (0.33710573010944656, 0.2298364507424795, 0.21...
# 1      12.483961  (0.29204919607792557, 0.1838327482898684, 0.26...
# 2      11.156876  (0.3647144936436182, 0.34352486587310693, 0.26...
# 3      13.021749  (0.37750275820063084, 0.3314346869455925, 0.26...
# 4      15.573313  (0.37506366949321446, 0.307545550997428, 0.264...
# 5      16.658806  (0.39552949656661573, 0.30849334420906704, 0.3...
# 6      17.809030  (0.32777961112100107, 0.37210383291819604, 0.2...
# 7      14.384162  (0.3689641486002354, 0.4091834665108762, 0.341...
# 8      12.223096  (0.3119342531936723, 0.3252144631742415, 0.265...
# 9      12.698859  (0.3489998266087804, 0.3887406137182897, 0.284...
#
#    time_modified_sec
# 0           0.634458
# 1           0.555246
# 2           0.396152
# 3           0.469462
# 4           0.645323
# 5           0.601220
# 6           0.577777
# 7           0.558413
# 8           0.494793
# 9           0.526790

# %%
# Out:
# 200.0
